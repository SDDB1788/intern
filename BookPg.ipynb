# %%
from bs4 import BeautifulSoup
import requests

# %%
url=requests.get("https://bookpage.com/")
url
# Out:
# <Response [200]>

# %%
bk=url.content

# %%
soup=BeautifulSoup(bk,'html.parser')

# %%
Albook=soup.findAll('div',{'class':'bp-well no-padding span6'})

# %%
first_bk_name=soup.find('div',{'class':'bp-well no-padding span6'}).h4.a.text
first_bk_name
# Out:
# 'The Ladies of the Secret Circus'

# %%
first_bk_genre=soup.find('p',{'class':'genre-links hidden-phone'}).a.text
first_bk_genre
# Out:
# "Children's"

# %%
soup.find('div',{'class':'row-fluid book-details-hero'})

# %%
first_bk_review=soup.find('div',{'class':'bp-well no-padding span6'}).p.text.replace('\n','')
first_bk_review
# Out:
# 'Review by Matthew Jackson'

# %%
soup.find('div',{'class':'span5 book-data'})

# %%
soup.find('div',{'class':'row-fluid book-details-hero'})

# %%
url1=requests.get("https://bookpage.com/reviews/26085-constance-sayers-ladies-secret-circus-fiction")
url1
# Out:
# <Response [200]>

# %%
url1.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Book Review - The Ladies of the Secret Circus by Constance Sayers | BookPage</title>\n<meta name="description" content="Constance Sayers\xe2\x80\x99 second novel is just as much about the secrets we keep in the name of family as it is about the spells we cast in the name of love.">\n<link rel="canonical" href="https://bookpage.com/reviews/26085-constance-sayers-ladies-secret-circus-fiction">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Book Review - The Ladies of the Secret Circus by Constance Sayers">\n<meta property="og:description" content="Constance Sayers\xe2\x80\x99 second novel is just as much about the secrets we keep in the name of family as it is about the spells we cast in the name of love.">\n<meta property="og:type" content="article">\n<meta property="og:url" content="https://b
# ...

# %%
soup1=BeautifulSoup(url1.content,'html.parser')

# %%
soup1.find('h4',class_=('sans')).text.replace('\n','')
# Out:
# 'Constance Sayers'

# %% [markdown]
# # Book 2

# %%
u=requests.get('https://bookpage.com/reviews/26154-c-l-clark-unbroken-science-fiction-fantasy')
u
# Out:
# <Response [200]>

# %%
pg=BeautifulSoup(u.content,'html.parser')
pg
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Review - The Unbroken by C.L. Clark | BookPage</title>
# <meta content="For all its disturbingly plausible grime, gore and occasional horror, The Unbroken is not a dark fantasy. There is a current of optimism that flows throughout." name="description"/>
# <link href="https://bookpage.com/reviews/26154-c-l-clark-unbroken-science-fiction-fantasy" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Review - The Unbroken by C.L. Clark" property="og:title"/>
# <meta content="For all its disturbingly plausible grime, gore and occasional horror, The Unbroken is not a dark fantasy. There is a current of optimism that flows throughout." property="og:description"/>
# <meta content="article" property="og:type"/>
# ...

# %%
Bknm=pg.find('div',class_='span5 book-data').h1.text.replace('\n','')
Bknm
# Out:
# 'The Unbroken'

# %%
author=pg.find('div',class_='span5 book-data').h4.text.replace('\n','')
author
# Out:
# 'C.L. Clark'

# %%
Reviewby=pg.find('div',class_='span5 book-data').a.text.replace('\n','')
Reviewby
# Out:
# 'Noah Fram'

# %%
Genre=pg.find('p',class_='genre-links').a.text
Genre
# Out:
# 'Science Fiction & Fantasy'

# %% [markdown]
# # Book 3

# %%
y=requests.get('https://bookpage.com/reviews/26085-constance-sayers-ladies-secret-circus-fiction')
y
# Out:
# <Response [200]>

# %%
t=BeautifulSoup(y.content,'html.parser')
t
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Review - The Ladies of the Secret Circus by Constance Sayers | BookPage</title>
# <meta content="Constance Sayers’ second novel is just as much about the secrets we keep in the name of family as it is about the spells we cast in the name of love." name="description"/>
# <link href="https://bookpage.com/reviews/26085-constance-sayers-ladies-secret-circus-fiction" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Review - The Ladies of the Secret Circus by Constance Sayers" property="og:title"/>
# <meta content="Constance Sayers’ second novel is just as much about the secrets we keep in the name of family as it is about the spells we cast in the name of love." property="og:description"/>
# <meta content="article" property="og:type"/>
# ...

# %%
Bk_name=t.find('div',class_='span5 book-data',).h1.text.replace('\n','')
Bk_name
# Out:
# 'The Ladies of the Secret Circus'

# %%
author=t.find('h4',class_='sans').text.replace('\n','')
author
# Out:
# 'Constance Sayers'

# %%
Reviewedby=t.find('p',class_='sans bold author-info').a.text
Reviewedby
# Out:
# 'Matthew Jackson'

# %%
genre=t.find('p',class_='genre-links').a.text
genre
# Out:
# 'Fiction'

# %% [markdown]
# # Book4

# %%
url=requests.get('https://bookpage.com/interviews/26051-robin-miles-audio')
url
# Out:
# <Response [200]>

# %%
pd=BeautifulSoup(url.content,'html.parser')
pd
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Author Interview - Robin Miles, author of Just as I Am | BookPage</title>
# <meta content="Narrator Robin Miles discusses the humbling and thrilling process of narrating Cicely Tyson's remarkable memoir, Just as I Am." name="description"/>
# <link href="https://bookpage.com/interviews/26051-robin-miles-audio" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Author Interview - Robin Miles, author of Just as I Am" property="og:title"/>
# <meta content="Narrator Robin Miles discusses the humbling and thrilling process of narrating Cicely Tyson's remarkable memoir, Just as I Am." property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://bookpage.com/interviews/26051-robin-miles-audio" property="og:url"/>
# ...

# %%
n=pd.find('h1',class_='italic').text.replace('\n','')
n
# Out:
# 'Robin Miles'

# %%
ed=pd.find('p',class_='sans bold author-info').text.replace('\n','')
ed
# Out:
# 'BookPage interview byCat, Deputy Editor'

# %% [markdown]
# # Book 5

# %%
u=requests.get('https://bookpage.com/reviews/26089-sarah-allen-breathing-underwater-childrens')
u
# Out:
# <Response [200]>

# %%
f=BeautifulSoup(u.content,'html.parser')
f
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Review - Breathing Underwater by Sarah Allen | BookPage</title>
# <meta content="Breathing Underwater is a lovely, important book that will be an especially welcome balm for any young reader who loves someone with mental illness." name="description"/>
# <link href="https://bookpage.com/reviews/26089-sarah-allen-breathing-underwater-childrens" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Review - Breathing Underwater by Sarah Allen" property="og:title"/>
# <meta content="Breathing Underwater is a lovely, important book that will be an especially welcome balm for any young reader who loves someone with mental illness." property="og:description"/>
# <meta content="article" property="og:type"/>
# ...

# %%
nm=f.find('h1',class_='italic').text.replace('\n','')
nm
# Out:
# '★ Breathing Underwater'

# %%
authr=f.find('h4',class_='sans').text.replace('\n','')
authr
# Out:
# 'Sarah Allen'

# %%
reviewedby=f.find('p',class_='sans bold author-info').a.text
reviewedby
# Out:
# 'Billie B. Little'
